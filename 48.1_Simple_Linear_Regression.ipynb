# %% [markdown]
# <a href="https://colab.research.google.com/github/swopnimghimire-123123/Machine-Learning-Journey/blob/main/48.1_Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/48_placement (1).csv")

# %%
df.sample(3)
# Out:
#      cgpa  package
# 78   6.59     2.21
# 159  8.71     4.08
# 81   6.10     2.20

# %%
plt.scatter(df["cgpa"],df["package"])
plt.xlabel("CGPA")
plt.ylabel("Package(In LPA)")
# Out:
# Text(0, 0.5, 'Package(In LPA)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X.sample(3)
# Out:
#      cgpa
# 159  8.71
# 23   6.19
# 95   6.63

# %%
y.sample(3)
# Out:
# 183    2.72
# 73     4.03
# 165    4.08
# Name: package, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test.sample(5)
# Out:
#      cgpa
# 126  5.91
# 57   6.60
# 64   7.36
# 6    6.73
# 71   7.47

# %%
y_test.sample(5)
# Out:
# 176    3.23
# 173    2.56
# 13     2.89
# 35     2.87
# 12     3.65
# Name: package, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-0.8961119222429144)

# %%
# y = mx + b

m * 9.5 + b
# Out:
# array([4.40443183])

# %%
m * 9.5 + b
# Out:
# array([4.40443183])

# %%
m * 100 + b
# Out:
# array([54.89908542])
